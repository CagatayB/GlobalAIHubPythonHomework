# %%
nameSurname = input("Please enter your name and surname")
age = int(input("Please enter your age: "))
gpaPoint = input("Please enter your school GPA point: ")
schoolName = input("Please enter your school name : ")
yearOfBirth = int(input("Please enter tyear of birth: "))
# Out:
# Please enter your name and surnameÇağatay BEŞER
# Please enter your age: 23
# Please enter your school GPA point: 3,54
# Please enter your school name : ADÜ
# Please enter tyear of birth: 1997

# %%
def typeOfInputs(x):
    print("Tip {}".format(type(x)))

# %%
message = (
...     f" {typeOfInputs(nameSurname)}. "
...     f" {typeOfInputs(age)}. "
...     f" {typeOfInputs(gpaPoint)}."
...     f" {typeOfInputs(schoolName)}."
...     f" {typeOfInputs(yearOfBirth)}."
... )
>>> message
# Out:
# Tip <class 'str'>
# Tip <class 'int'>
# Tip <class 'str'>
# Tip <class 'str'>
# Tip <class 'int'>
# ' None.  None.  None. None. None.'

# %%
print("Users Name and Surname is: {}".format(nameSurname))
print("Users Age is: " + str(age))
print("Users GPA Point is:" + str(gpaPoint))
print(f"School Name: {schoolName}")
print("Year of Birth: {}".format(yearOfBirth))
# Out:
# Users Name and Surname is: Çağatay BEŞER
# Users Age is: 23
# Users GPA Point is:3,54
# School Name: ADÜ
# Year of Birth: 1997
